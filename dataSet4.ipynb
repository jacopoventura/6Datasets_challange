# %%
# Import packages for data analysis
import os    # OS module provides the interface with the operating system and allows to use it
import tarfile
from six.moves import urllib
import pandas as pd     # Pandas: python library for large data manipulation and analysis. 
                        # Dataset will be saved as Pands dataset
import numpy as np
import matplotlib.pyplot as plt

# this command is very important in Jupyter: figures must be showed directly in the notebook!!!
# %matplotlib inline

# disable warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# step 1: acquire dataset
data_path='C:/Users/jacopo/Desktop/schaeffler/testData4.csv'
dataset = pd.read_csv(data_path,sep=';')   # dataset as pandas dataset

print('Overview of the dataset: size of dataset and type of data:\n')
dataset.info()

print('\nDescriptive statistics of the dataset:')
dataset.describe()
# Out:
# Overview of the dataset: size of dataset and type of data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
# a    10000 non-null float64
# b    10000 non-null float64
# c    10000 non-null float64
# d    10000 non-null int64
# e    10000 non-null int64
# t    10000 non-null int64
# dtypes: float64(3), int64(3)
# memory usage: 468.8 KB
#
# Descriptive statistics of the dataset:
#                   a             b             c             d             e  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     503.149941    500.534034     49.786942     22.029800      4.551400
# std      289.284645    289.302811     29.122688     10.776304      2.851275
# min        0.040000      0.010000      0.000000     -5.000000      0.000000
# 25%      254.777500    248.090000     24.367500     14.000000      2.000000
# 50%      503.225000    499.310000     49.905000     22.000000      5.000000
# 75%      754.722500    752.260000     75.260000     30.000000      7.000000
# max      999.900000    999.760000     99.990000     49.000000      9.000000
#
#                   t
# count  10000.000000
# mean      13.569500
# std        4.997046
# min        0.000000
# 25%       10.000000
# 50%       14.000000
# 75%       17.000000
# max       27.000000

# %% [markdown]
# Larger dataset, t and d are normal distributions

# %%
# generate scatter matrix
from pandas.plotting import scatter_matrix

print('Scatter matrix of data:')
scatter_matrix(dataset, figsize=(16, 12))
# Out:
# Scatter matrix of data:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74FA3320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B7502D6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B752EDE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74BE6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74BF7F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74BF7FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74D102E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74D78F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74DDD940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74E56C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74EB9BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74EFC518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B7631B198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76329710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B763E0B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B74DB9240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B7647E4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B764DC2B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76545F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B765A8908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76620BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76684B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B766C54E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76755160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B767656D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B7681CB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B7687C908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B768E95C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76947F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B769C9278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76A2E208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76A68B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76AF47B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76B05DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76BC6198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B76C13F60>]], dtype=object)

# %%
import seaborn as sns

# check linear correlation through Pearson's r
corr_matrix = dataset.corr()

print('Display correlation matrix')
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(corr_matrix, 
            mask=np.zeros_like(corr_matrix, dtype=np.bool), 
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# Display correlation matrix
