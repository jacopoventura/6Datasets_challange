# %%
# Import packages for data analysis
import os    # OS module provides the interface with the operating system and allows to use it
import tarfile
from six.moves import urllib
import pandas as pd     # Pandas: python library for large data manipulation and analysis. 
                        # Dataset will be saved as Pands dataset
import numpy as np
import matplotlib.pyplot as plt

# this command is very important in Jupyter: figures must be showed directly in the notebook!!!
# %matplotlib inline

# disable warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# step 1: acquire dataset
data_path='C:/Users/jacopo/Desktop/schaeffler/testData4.csv'
dataset = pd.read_csv(data_path,sep=';')   # dataset as pandas dataset

print('Overview of the dataset: size of dataset and type of data:\n')
dataset.info()

print('\nDescriptive statistics of the dataset:')
dataset.describe()
# Out:
# Overview of the dataset: size of dataset and type of data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
# a    10000 non-null float64
# b    10000 non-null float64
# c    10000 non-null float64
# d    10000 non-null int64
# e    10000 non-null int64
# t    10000 non-null int64
# dtypes: float64(3), int64(3)
# memory usage: 468.8 KB
#
# Descriptive statistics of the dataset:
#                   a             b             c             d             e  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     503.149941    500.534034     49.786942     22.029800      4.551400
# std      289.284645    289.302811     29.122688     10.776304      2.851275
# min        0.040000      0.010000      0.000000     -5.000000      0.000000
# 25%      254.777500    248.090000     24.367500     14.000000      2.000000
# 50%      503.225000    499.310000     49.905000     22.000000      5.000000
# 75%      754.722500    752.260000     75.260000     30.000000      7.000000
# max      999.900000    999.760000     99.990000     49.000000      9.000000
#
#                   t
# count  10000.000000
# mean      13.569500
# std        4.997046
# min        0.000000
# 25%       10.000000
# 50%       14.000000
# 75%       17.000000
# max       27.000000

# %%
# Histograms of data
dataset.hist(bins=10, figsize=(20,15))
plt.show()

# %% [markdown]
# Larger dataset, t and d are normal distributions

# %%
# generate scatter matrix
from pandas.plotting import scatter_matrix

print('Scatter matrix of data:')
scatter_matrix(dataset, figsize=(16, 12))
# Out:
# Scatter matrix of data:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD8D838898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9102A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9108A208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD91146AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD911AA2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD911AA2E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD91277C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD912F2940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD913592B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD913956A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9141EBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9142F710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD914ECA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90D5BBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90E43828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90F380B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90F803C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90F07FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90EDE6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90F4DB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD907BE5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90D24940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90CF2E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90C17780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90BCFE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD915A75C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD91605860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9167E518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD916DAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9171C278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CD917A57B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD917B7F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD918715F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD90EB5588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD919256A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CD9197CE10>]], dtype=object)
